# %%
import pandas as pd

train_data_s3path = "s3://sagemaker-us-east-1-980831117329/data/boston/train/data"
pd.read_csv(train_data_s3path,
            names=["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS",
                   "RAD", "TAX", "PTRATIO", "B", "LSTAT", "price"])
# Out:
#      CRIM        ZN  INDUS   CHAS  NOX     RM    AGE    DIS     RAD   TAX  \
# 0    28.7   0.02985    0.0   2.18  0.0  0.458  6.430   58.7  6.0622   3.0
# 1    17.0   1.41385    0.0  19.58  1.0  0.871  6.129   96.0  1.7494   5.0
# 2    11.9  20.71620    0.0  18.10  0.0  0.659  4.138  100.0  1.1781  24.0
# 3    43.5   0.54050   20.0   3.97  0.0  0.575  7.470   52.6  2.8720   5.0
# 4    14.5   0.98843    0.0   8.14  0.0  0.538  5.813  100.0  4.0952   4.0
# ..    ...       ...    ...    ...  ...    ...    ...    ...     ...   ...
# 279  13.4   6.71772    0.0  18.10  0.0  0.713  6.749   92.6  2.3236  24.0
# 280  13.3   0.24980    0.0  21.89  0.0  0.624  5.857   98.2  1.6686   4.0
# 281  19.4   0.26363    0.0   8.56  0.0  0.520  6.229   91.2  2.5451   5.0
# 282  12.5   5.87205    0.0  18.10  0.0  0.693  6.405   96.0  1.6768  24.0
# 283  23.2   5.29305    0.0  18.10  0.0  0.700  6.051   82.5  2.1678  24.0
#
#      PTRATIO     B   LSTAT  price
# 0      222.0  18.7  394.12   5.21
# 1      403.0  14.7  321.02  15.12
# 2      666.0  20.2  370.22  23.34
# 3      264.0  13.0  390.30   3.16
# 4      307.0  21.0  394.54  19.88
# ..       ...   ...     ...    ...
# 279    666.0  20.2    0.32  17.44
# 280    437.0  21.2  392.04  21.32
# 281    384.0  20.9  391.23  15.55
# 282    666.0  20.2  396.90  19.37
# 283    666.0  20.2  378.38  18.76
#
# [284 rows x 14 columns]

# %%
import boto3
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri

sess = sagemaker.Session()
bucket = sess.default_bucket()
role = get_execution_role()

container = sagemaker.image_uris.retrieve("linear-learner", boto3.Session().region_name)

# %%
from time import gmtime, strftime

job_name = f"boston-house-price-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
linear = sagemaker.estimator.Estimator(container,
                                       role,
                                       instance_count=1,
                                       instance_type='ml.c4.xlarge',
                                       sagemaker_session=sagemaker.Session())

linear.set_hyperparameters(feature_dim=13,
                           mini_batch_size=100,
                           predictor_type='regressor')

s3_input_train = sagemaker.inputs.TrainingInput(s3_data=train_data_s3path, content_type='text/csv')
linear.fit(
    {"train": s3_input_train},
    job_name=job_name
)
# Out:
# 2022-07-26 04:09:13 Starting - Starting the training job...
# 2022-07-26 04:09:40 Starting - Preparing the instances for trainingProfilerReport-1658808553: InProgress
# .........
# 2022-07-26 04:11:13 Downloading - Downloading input data......
# 2022-07-26 04:12:13 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [07/26/2022 04:12:12 INFO 140426084742976] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [07/26/2022 04:12:12 INFO 140426084742976] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'mini_batch_size': '100', 'predictor_type': 'regressor'}
# [07/26/2022 04:12:12 INFO 140426084742976] Final configuration: {'mini_batch_size': '100', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [07/26/2022 04:12:12 WARNING 140426084742976] Loggers have already been setup.
# Process 1 is a worker.
# [07/26/2022 04:12:12 INFO 140426084742976] Using default worker.
# [07/26/2022 04:12:12 INFO 140426084742976] Checkpoint loading and saving are disabled.
# [07/26/2022 04:12:13 INFO 140426084742976] Create Store: local
# [07/26/2022 04:12:13 INFO 140426084742976] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb715748f50>
# [07/26/2022 04:12:13 INFO 140426084742976] Scaling model computed with parameters:
#  {'stdev_label':
# [9.149645]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [5.59209585e+00 2.47883549e+01 6.63336849e+00 2.17944950e-01
#  1.17713206e-01 7.54798889e-01 2.87664700e+01 2.09919357e+00
#  8.46212769e+00 1.62864944e+02 2.24936867e+00 9.14199371e+01
#  6.66884851e+00]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [23.264]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [2.89792681e+00 1.30000000e+01 1.05990505e+01 4.99999970e-02
#  5.47685504e-01 6.30367517e+00 6.69510040e+01 3.87596750e+00
#  9.18000031e+00 3.98889984e+02 1.83684998e+01 3.55891693e+02
#  1.19293995e+01]
# <NDArray 13 @cpu(0)>}
# [07/26/2022 04:12:13 INFO 140426084742976] nvidia-smi: took 0.031 seconds to run.
# [07/26/2022 04:12:13 INFO 140426084742976] nvidia-smi identified 0 GPUs.
# [07/26/2022 04:12:13 INFO 140426084742976] Number of GPUs being used: 0
# #metrics {"StartTime": 1658808733.2197185, "EndTime": 1658808733.2197528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 384.0, "count": 1, "min": 384, "max": 384}, "Total Batches Seen": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# #metrics {"StartTime": 1658808733.310838, "EndTime": 1658808733.3109221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.956076774597168, "count": 1, "min": 0.956076774597168, "max": 0.956076774597168}}}
# #metrics {"StartTime": 1658808733.311085, "EndTime": 1658808733.311107, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8436017608642579, "count": 1, "min": 0.8436017608642579, "max": 0.8436017608642579}}}
# #metrics {"StartTime": 1658808733.3111644, "EndTime": 1658808733.3111804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.3033709716796875, "count": 1, "min": 1.3033709716796875, "max": 1.3033709716796875}}}
# #metrics {"StartTime": 1658808733.3112304, "EndTime": 1658808733.3112452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8573035049438477, "count": 1, "min": 0.8573035049438477, "max": 0.8573035049438477}}}
# #metrics {"StartTime": 1658808733.3113494, "EndTime": 1658808733.311368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.4092301177978515, "count": 1, "min": 1.4092301177978515, "max": 1.4092301177978515}}}
# #metrics {"StartTime": 1658808733.3114214, "EndTime": 1658808733.311436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.3445454025268555, "count": 1, "min": 1.3445454025268555, "max": 1.3445454025268555}}}
# #metrics {"StartTime": 1658808733.3114862, "EndTime": 1658808733.3115013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.445947799682617, "count": 1, "min": 1.445947799682617, "max": 1.445947799682617}}}
# #metrics {"StartTime": 1658808733.3115516, "EndTime": 1658808733.3115664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.440826759338379, "count": 1, "min": 1.440826759338379, "max": 1.440826759338379}}}
# #metrics {"StartTime": 1658808733.311613, "EndTime": 1658808733.3116288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.9045006942749023, "count": 1, "min": 0.9045006942749023, "max": 0.9045006942749023}}}
# #metrics {"StartTime": 1658808733.3116748, "EndTime": 1658808733.3116903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.3809427261352538, "count": 1, "min": 1.3809427261352538, "max": 1.3809427261352538}}}
# #metrics {"StartTime": 1658808733.3117466, "EndTime": 1658808733.311759, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8483488082885742, "count": 1, "min": 0.8483488082885742, "max": 0.8483488082885742}}}
# #metrics {"StartTime": 1658808733.311808, "EndTime": 1658808733.311826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0633536529541017, "count": 1, "min": 1.0633536529541017, "max": 1.0633536529541017}}}
# #metrics {"StartTime": 1658808733.3119063, "EndTime": 1658808733.3119252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.393094024658203, "count": 1, "min": 1.393094024658203, "max": 1.393094024658203}}}
# #metrics {"StartTime": 1658808733.3119817, "EndTime": 1658808733.3119938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 1.4725914764404298, "count": 1, "min": 1.4725914764404298, "max": 1.4725914764404298}}}
# #metrics {"StartTime": 1658808733.3120434, "EndTime": 1658808733.3120573, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.4304295349121094, "count": 1, "min": 1.4304295349121094, "max": 1.4304295349121094}}}
# #metrics {"StartTime": 1658808733.3121014, "EndTime": 1658808733.3121157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.3489308547973633, "count": 1, "min": 1.3489308547973633, "max": 1.3489308547973633}}}
# #metrics {"StartTime": 1658808733.3121438, "EndTime": 1658808733.3121512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 1.0283449935913085, "count": 1, "min": 1.0283449935913085, "max": 1.0283449935913085}}}
# #metrics {"StartTime": 1658808733.3121736, "EndTime": 1658808733.3121803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8302747726440429, "count": 1, "min": 0.8302747726440429, "max": 0.8302747726440429}}}
# #metrics {"StartTime": 1658808733.312202, "EndTime": 1658808733.3122084, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.2143042755126954, "count": 1, "min": 1.2143042755126954, "max": 1.2143042755126954}}}
# #metrics {"StartTime": 1658808733.3122296, "EndTime": 1658808733.3122365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 1.0278982162475585, "count": 1, "min": 1.0278982162475585, "max": 1.0278982162475585}}}
# #metrics {"StartTime": 1658808733.3122787, "EndTime": 1658808733.3122942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 1.2862685012817383, "count": 1, "min": 1.2862685012817383, "max": 1.2862685012817383}}}
# #metrics {"StartTime": 1658808733.3123527, "EndTime": 1658808733.3123698, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.4316087341308594, "count": 1, "min": 1.4316087341308594, "max": 1.4316087341308594}}}
# #metrics {"StartTime": 1658808733.3124225, "EndTime": 1658808733.3124366, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.244213752746582, "count": 1, "min": 1.244213752746582, "max": 1.244213752746582}}}
# #metrics {"StartTime": 1658808733.3124893, "EndTime": 1658808733.312505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.3344744110107423, "count": 1, "min": 1.3344744110107423, "max": 1.3344744110107423}}}
# #metrics {"StartTime": 1658808733.312556, "EndTime": 1658808733.3125713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9612279891967773, "count": 1, "min": 0.9612279891967773, "max": 0.9612279891967773}}}
# #metrics {"StartTime": 1658808733.3126333, "EndTime": 1658808733.3126512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9629294967651367, "count": 1, "min": 0.9629294967651367, "max": 0.9629294967651367}}}
# #metrics {"StartTime": 1658808733.3127134, "EndTime": 1658808733.312731, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.232754020690918, "count": 1, "min": 1.232754020690918, "max": 1.232754020690918}}}
# #metrics {"StartTime": 1658808733.312784, "EndTime": 1658808733.3128, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.1188871383666992, "count": 1, "min": 1.1188871383666992, "max": 1.1188871383666992}}}
# #metrics {"StartTime": 1658808733.3128524, "EndTime": 1658808733.3128684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.5214171600341797, "count": 1, "min": 1.5214171600341797, "max": 1.5214171600341797}}}
# #metrics {"StartTime": 1658808733.312919, "EndTime": 1658808733.3129337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.4778781127929688, "count": 1, "min": 1.4778781127929688, "max": 1.4778781127929688}}}
# #metrics {"StartTime": 1658808733.3129845, "EndTime": 1658808733.3129997, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.498769760131836, "count": 1, "min": 1.498769760131836, "max": 1.498769760131836}}}
# #metrics {"StartTime": 1658808733.3130624, "EndTime": 1658808733.31308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.46141845703125, "count": 1, "min": 1.46141845703125, "max": 1.46141845703125}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.956076774597168
# [07/26/2022 04:12:13 INFO 140426084742976] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.8302747726440429
# [07/26/2022 04:12:13 INFO 140426084742976] Epoch 0: Loss improved. Updating best model
# [07/26/2022 04:12:13 INFO 140426084742976] Saving model for epoch: 0
# [07/26/2022 04:12:13 INFO 140426084742976] Saved checkpoint to "/tmp/tmpkm5j6s6e/mx-mod-0000.params"
# [07/26/2022 04:12:13 INFO 140426084742976] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1658808733.2200732, "EndTime": 1658808733.3318324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 668.0, "count": 1, "min": 668, "max": 668}, "Total Batches Seen": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #throughput_metric: host=algo-1, train throughput=2537.3727748133474 records/second
# #metrics {"StartTime": 1658808733.4024534, "EndTime": 1658808733.4025023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8618395614624024, "count": 1, "min": 0.8618395614624024, "max": 0.8618395614624024}}}
# #metrics {"StartTime": 1658808733.4025707, "EndTime": 1658808733.4025884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7648779296875, "count": 1, "min": 0.7648779296875, "max": 0.7648779296875}}}
# #metrics {"StartTime": 1658808733.4026515, "EndTime": 1658808733.4026701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.1683261489868164, "count": 1, "min": 1.1683261489868164, "max": 1.1683261489868164}}}
# #metrics {"StartTime": 1658808733.402717, "EndTime": 1658808733.4027345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.779376106262207, "count": 1, "min": 0.779376106262207, "max": 0.779376106262207}}}
# #metrics {"StartTime": 1658808733.4027805, "EndTime": 1658808733.402799, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7196257781982421, "count": 1, "min": 0.7196257781982421, "max": 0.7196257781982421}}}
# #metrics {"StartTime": 1658808733.4028418, "EndTime": 1658808733.4028587, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.8992077255249024, "count": 1, "min": 0.8992077255249024, "max": 0.8992077255249024}}}
# #metrics {"StartTime": 1658808733.4029047, "EndTime": 1658808733.4029214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.9662519454956054, "count": 1, "min": 0.9662519454956054, "max": 0.9662519454956054}}}
# #metrics {"StartTime": 1658808733.4029682, "EndTime": 1658808733.4029822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.9235563278198242, "count": 1, "min": 0.9235563278198242, "max": 0.9235563278198242}}}
# #metrics {"StartTime": 1658808733.4030385, "EndTime": 1658808733.4030566, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8272567367553711, "count": 1, "min": 0.8272567367553711, "max": 0.8272567367553711}}}
# #metrics {"StartTime": 1658808733.4031167, "EndTime": 1658808733.4031334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.2381866836547852, "count": 1, "min": 1.2381866836547852, "max": 1.2381866836547852}}}
# #metrics {"StartTime": 1658808733.4031858, "EndTime": 1658808733.4032042, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7773635101318359, "count": 1, "min": 0.7773635101318359, "max": 0.7773635101318359}}}
# #metrics {"StartTime": 1658808733.403247, "EndTime": 1658808733.403264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.9579907608032227, "count": 1, "min": 0.9579907608032227, "max": 0.9579907608032227}}}
# #metrics {"StartTime": 1658808733.4033067, "EndTime": 1658808733.4033248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.8963440704345703, "count": 1, "min": 0.8963440704345703, "max": 0.8963440704345703}}}
# #metrics {"StartTime": 1658808733.4033687, "EndTime": 1658808733.4033854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.8226857376098633, "count": 1, "min": 0.8226857376098633, "max": 0.8226857376098633}}}
# #metrics {"StartTime": 1658808733.4034345, "EndTime": 1658808733.403451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.6959576034545898, "count": 1, "min": 0.6959576034545898, "max": 0.6959576034545898}}}
# #metrics {"StartTime": 1658808733.4034996, "EndTime": 1658808733.4035158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.9355984497070312, "count": 1, "min": 0.9355984497070312, "max": 0.9355984497070312}}}
# #metrics {"StartTime": 1658808733.403576, "EndTime": 1658808733.4035943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9280212020874024, "count": 1, "min": 0.9280212020874024, "max": 0.9280212020874024}}}
# #metrics {"StartTime": 1658808733.4036388, "EndTime": 1658808733.403654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7604192733764649, "count": 1, "min": 0.7604192733764649, "max": 0.7604192733764649}}}
# #metrics {"StartTime": 1658808733.4036996, "EndTime": 1658808733.4037151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.103444175720215, "count": 1, "min": 1.103444175720215, "max": 1.103444175720215}}}
# #metrics {"StartTime": 1658808733.4037683, "EndTime": 1658808733.4037843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9330192947387695, "count": 1, "min": 0.9330192947387695, "max": 0.9330192947387695}}}
# #metrics {"StartTime": 1658808733.403835, "EndTime": 1658808733.4038508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.5698828315734863, "count": 1, "min": 0.5698828315734863, "max": 0.5698828315734863}}}
# #metrics {"StartTime": 1658808733.4039626, "EndTime": 1658808733.4039805, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.8622650527954101, "count": 1, "min": 0.8622650527954101, "max": 0.8622650527954101}}}
# #metrics {"StartTime": 1658808733.404034, "EndTime": 1658808733.4040492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.6781701850891113, "count": 1, "min": 0.6781701850891113, "max": 0.6781701850891113}}}
# #metrics {"StartTime": 1658808733.404101, "EndTime": 1658808733.4041162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.6324570655822754, "count": 1, "min": 0.6324570655822754, "max": 0.6324570655822754}}}
# #metrics {"StartTime": 1658808733.4041684, "EndTime": 1658808733.4041843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9548441696166993, "count": 1, "min": 0.9548441696166993, "max": 0.9548441696166993}}}
# #metrics {"StartTime": 1658808733.404239, "EndTime": 1658808733.4042547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9766245269775391, "count": 1, "min": 0.9766245269775391, "max": 0.9766245269775391}}}
# #metrics {"StartTime": 1658808733.4043033, "EndTime": 1658808733.4043179, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.1471413803100585, "count": 1, "min": 1.1471413803100585, "max": 1.1471413803100585}}}
# #metrics {"StartTime": 1658808733.4043696, "EndTime": 1658808733.4043863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.088268928527832, "count": 1, "min": 1.088268928527832, "max": 1.088268928527832}}}
# #metrics {"StartTime": 1658808733.404438, "EndTime": 1658808733.4044547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.024997444152832, "count": 1, "min": 1.024997444152832, "max": 1.024997444152832}}}
# #metrics {"StartTime": 1658808733.4045074, "EndTime": 1658808733.4045212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.1043048095703125, "count": 1, "min": 1.1043048095703125, "max": 1.1043048095703125}}}
# #metrics {"StartTime": 1658808733.4045713, "EndTime": 1658808733.4045875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9852645111083984, "count": 1, "min": 0.9852645111083984, "max": 0.9852645111083984}}}
# #metrics {"StartTime": 1658808733.4046347, "EndTime": 1658808733.4046502, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0324021148681641, "count": 1, "min": 1.0324021148681641, "max": 1.0324021148681641}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.8618395614624024
# [07/26/2022 04:12:13 INFO 140426084742976] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.5698828315734863
# [07/26/2022 04:12:13 INFO 140426084742976] Epoch 1: Loss improved. Updating best model
# [07/26/2022 04:12:13 INFO 140426084742976] Saving model for epoch: 1
# [07/26/2022 04:12:13 INFO 140426084742976] Saved checkpoint to "/tmp/tmpvu81bqz3/mx-mod-0000.params"
# [07/26/2022 04:12:13 INFO 140426084742976] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1658808733.3321671, "EndTime": 1658808733.4149663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 952.0, "count": 1, "min": 952, "max": 952}, "Total Batches Seen": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #throughput_metric: host=algo-1, train throughput=3424.837153938822 records/second
# #metrics {"StartTime": 1658808733.4887257, "EndTime": 1658808733.4887972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7856096649169921, "count": 1, "min": 0.7856096649169921, "max": 0.7856096649169921}}}
# #metrics {"StartTime": 1658808733.4888697, "EndTime": 1658808733.4888883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.7042380905151367, "count": 1, "min": 0.7042380905151367, "max": 0.7042380905151367}}}
# #metrics {"StartTime": 1658808733.4889557, "EndTime": 1658808733.4889734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.0522720336914062, "count": 1, "min": 1.0522720336914062, "max": 1.0522720336914062}}}
# #metrics {"StartTime": 1658808733.4890332, "EndTime": 1658808733.4890501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.7187614440917969, "count": 1, "min": 0.7187614440917969, "max": 0.7187614440917969}}}
# #metrics {"StartTime": 1658808733.4891043, "EndTime": 1658808733.4891205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.9207118225097656, "count": 1, "min": 0.9207118225097656, "max": 0.9207118225097656}}}
# #metrics {"StartTime": 1658808733.4891763, "EndTime": 1658808733.4891934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.8960817718505859, "count": 1, "min": 0.8960817718505859, "max": 0.8960817718505859}}}
# #metrics {"StartTime": 1658808733.489247, "EndTime": 1658808733.489263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.9150591278076172, "count": 1, "min": 0.9150591278076172, "max": 0.9150591278076172}}}
# #metrics {"StartTime": 1658808733.489322, "EndTime": 1658808733.4893372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.9063051605224609, "count": 1, "min": 0.9063051605224609, "max": 0.9063051605224609}}}
# #metrics {"StartTime": 1658808733.4893878, "EndTime": 1658808733.489405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.767288818359375, "count": 1, "min": 0.767288818359375, "max": 0.767288818359375}}}
# #metrics {"StartTime": 1658808733.4894583, "EndTime": 1658808733.4894748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.1144393539428712, "count": 1, "min": 1.1144393539428712, "max": 1.1144393539428712}}}
# #metrics {"StartTime": 1658808733.4895275, "EndTime": 1658808733.4895437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.7235661315917968, "count": 1, "min": 0.7235661315917968, "max": 0.7235661315917968}}}
# #metrics {"StartTime": 1658808733.4895954, "EndTime": 1658808733.489618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.8713918685913086, "count": 1, "min": 0.8713918685913086, "max": 0.8713918685913086}}}
# #metrics {"StartTime": 1658808733.4896681, "EndTime": 1658808733.489686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.8981487655639648, "count": 1, "min": 0.8981487655639648, "max": 0.8981487655639648}}}
# #metrics {"StartTime": 1658808733.4897368, "EndTime": 1658808733.4897528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.9135101318359375, "count": 1, "min": 0.9135101318359375, "max": 0.9135101318359375}}}
# #metrics {"StartTime": 1658808733.4898038, "EndTime": 1658808733.48982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.9386724090576172, "count": 1, "min": 0.9386724090576172, "max": 0.9386724090576172}}}
# #metrics {"StartTime": 1658808733.4898713, "EndTime": 1658808733.4898872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.9058255767822265, "count": 1, "min": 0.9058255767822265, "max": 0.9058255767822265}}}
# #metrics {"StartTime": 1658808733.4899423, "EndTime": 1658808733.4899592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.8466054153442383, "count": 1, "min": 0.8466054153442383, "max": 0.8466054153442383}}}
# #metrics {"StartTime": 1658808733.4900103, "EndTime": 1658808733.4900289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.7061321258544921, "count": 1, "min": 0.7061321258544921, "max": 0.7061321258544921}}}
# #metrics {"StartTime": 1658808733.4900928, "EndTime": 1658808733.4901142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.0115203475952148, "count": 1, "min": 1.0115203475952148, "max": 1.0115203475952148}}}
# #metrics {"StartTime": 1658808733.490171, "EndTime": 1658808733.4901853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.8562688446044922, "count": 1, "min": 0.8562688446044922, "max": 0.8562688446044922}}}
# #metrics {"StartTime": 1658808733.4902527, "EndTime": 1658808733.4902728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.9694907760620117, "count": 1, "min": 0.9694907760620117, "max": 0.9694907760620117}}}
# #metrics {"StartTime": 1658808733.4903278, "EndTime": 1658808733.4903457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.9124469375610351, "count": 1, "min": 0.9124469375610351, "max": 0.9124469375610351}}}
# #metrics {"StartTime": 1658808733.4903932, "EndTime": 1658808733.4904115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.019469337463379, "count": 1, "min": 1.019469337463379, "max": 1.019469337463379}}}
# #metrics {"StartTime": 1658808733.4904647, "EndTime": 1658808733.4904802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.991635856628418, "count": 1, "min": 0.991635856628418, "max": 0.991635856628418}}}
# #metrics {"StartTime": 1658808733.4905334, "EndTime": 1658808733.4905505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9552647399902344, "count": 1, "min": 0.9552647399902344, "max": 0.9552647399902344}}}
# #metrics {"StartTime": 1658808733.490603, "EndTime": 1658808733.4906192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.980073356628418, "count": 1, "min": 0.980073356628418, "max": 0.980073356628418}}}
# #metrics {"StartTime": 1658808733.4906716, "EndTime": 1658808733.490689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.0695667266845703, "count": 1, "min": 1.0695667266845703, "max": 1.0695667266845703}}}
# #metrics {"StartTime": 1658808733.490753, "EndTime": 1658808733.4907713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.056729507446289, "count": 1, "min": 1.056729507446289, "max": 1.056729507446289}}}
# #metrics {"StartTime": 1658808733.490826, "EndTime": 1658808733.4908419, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.4643863677978515, "count": 1, "min": 1.4643863677978515, "max": 1.4643863677978515}}}
# #metrics {"StartTime": 1658808733.4908934, "EndTime": 1658808733.490909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.3787506866455077, "count": 1, "min": 1.3787506866455077, "max": 1.3787506866455077}}}
# #metrics {"StartTime": 1658808733.4909537, "EndTime": 1658808733.4909635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.5828465270996093, "count": 1, "min": 1.5828465270996093, "max": 1.5828465270996093}}}
# #metrics {"StartTime": 1658808733.4909892, "EndTime": 1658808733.4909961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.6904183197021485, "count": 1, "min": 1.6904183197021485, "max": 1.6904183197021485}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.7856096649169921
# [07/26/2022 04:12:13 INFO 140426084742976] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.7042380905151367
# [07/26/2022 04:12:13 INFO 140426084742976] Saving model for epoch: 2
# [07/26/2022 04:12:13 INFO 140426084742976] Saved checkpoint to "/tmp/tmptc8hnpxd/mx-mod-0000.params"
# [07/26/2022 04:12:13 INFO 140426084742976] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1658808733.4151995, "EndTime": 1658808733.499171, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1236.0, "count": 1, "min": 1236, "max": 1236}, "Total Batches Seen": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [07/26/2022 04:12:13 INFO 140426084742976] #throughput_metric: host=algo-1, train throughput=3378.4355954893017 records/second
# #metrics {"StartTime": 1658808733.5679781, "EndTime": 1658808733.568031, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7218565368652343, "count": 1, "min": 0.7218565368652343, "max": 0.7218565368652343}}}
# #metrics {"StartTime": 1658808733.568104, "EndTime": 1658808733.5681224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.6554980087280273, "count": 1, "min": 0.6554980087280273, "max": 0.6554980087280273}}}
# #metrics {"StartTime": 1658808733.5681875, "EndTime": 1658808733.5682044, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.9499516296386719, "count": 1, "min": 0.9499516296386719, "max": 0.9499516296386719}}}
# #metrics {"StartTime": 1658808733.5685954, "EndTime": 1658808733.5686185, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.6697918319702149, "count": 1, "min": 0.6697918319702149, "max": 0.6697918319702149}}}
# #metrics {"StartTime": 1658808733.568682, "EndTime": 1658808733.5686998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.48883739471435544, "count": 1, "min": 0.48883739471435544, "max": 0.48883739471435544}}}
# #metrics {"StartTime": 1658808733.568752, "EndTime": 1658808733.5687692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.5235836219787597, "count": 1, "min": 0.5235836219787597, "max": 0.5235836219787597}}}
# #metrics {"StartTime": 1658808733.568821, "EndTime": 1658808733.568837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.5285030746459961, "count": 1, "min": 0.5285030746459961, "max": 0.5285030746459961}}}
# #metrics {"StartTime": 1658808733.5689237, "EndTime": 1658808733.5689435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.5253855323791504, "count": 1, "min": 0.5253855323791504, "max": 0.5253855323791504}}}
# #metrics {"StartTime": 1658808733.5689936, "EndTime": 1658808733.5690079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.7185756301879883, "count": 1, "min": 0.7185756301879883, "max": 0.7185756301879883}}}
# #metrics {"StartTime": 1658808733.5690541, "EndTime": 1658808733.5690684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.0043566513061524, "count": 1, "min": 1.0043566513061524, "max": 1.0043566513061524}}}
# #metrics {"StartTime": 1658808733.5691159, "EndTime": 1658808733.5691297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6796815109252929, "count": 1, "min": 0.6796815109252929, "max": 0.6796815109252929}}}
# #metrics {"StartTime": 1658808733.5691793, "EndTime": 1658808733.569194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.7990437316894531, "count": 1, "min": 0.7990437316894531, "max": 0.7990437316894531}}}
# #metrics {"StartTime": 1658808733.5692434, "EndTime": 1658808733.5692582, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.5446534538269043, "count": 1, "min": 0.5446534538269043, "max": 0.5446534538269043}}}
# #metrics {"StartTime": 1658808733.5693092, "EndTime": 1658808733.5693247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.5052359771728515, "count": 1, "min": 0.5052359771728515, "max": 0.5052359771728515}}}
# #metrics {"StartTime": 1658808733.569375, "EndTime": 1658808733.5693903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.5014996147155761, "count": 1, "min": 0.5014996147155761, "max": 0.5014996147155761}}}
# #metrics {"StartTime": 1658808733.5694504, "EndTime": 1658808733.569468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.5369022750854492, "count": 1, "min": 0.5369022750854492, "max": 0.5369022750854492}}}
# #metrics {"StartTime": 1658808733.5695195, "EndTime": 1658808733.5696108, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7787652969360351, "count": 1, "min": 0.7787652969360351, "max": 0.7787652969360351}}}
# #metrics {"StartTime": 1658808733.5696735, "EndTime": 1658808733.5696917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.6611236763000489, "count": 1, "min": 0.6611236763000489, "max": 0.6611236763000489}}}
# #metrics {"StartTime": 1658808733.5697613, "EndTime": 1658808733.5697794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.9327822875976562, "count": 1, "min": 0.9327822875976562, "max": 0.9327822875976562}}}
# #metrics {"StartTime": 1658808733.5698287, "EndTime": 1658808733.5698438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7916881942749023, "count": 1, "min": 0.7916881942749023, "max": 0.7916881942749023}}}
# #metrics {"StartTime": 1658808733.5698853, "EndTime": 1658808733.569898, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.4326530075073242, "count": 1, "min": 0.4326530075073242, "max": 0.4326530075073242}}}
# #metrics {"StartTime": 1658808733.5699558, "EndTime": 1658808733.5699742, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.6190632057189941, "count": 1, "min": 0.6190632057189941, "max": 0.6190632057189941}}}
# #metrics {"StartTime": 1658808733.5700393, "EndTime": 1658808733.5700533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.534395523071289, "count": 1, "min": 0.534395523071289, "max": 0.534395523071289}}}
# ...
# [07/26/2022 04:12:14 INFO 140426084742976] Saving model for epoch: 12
# [07/26/2022 04:12:14 INFO 140426084742976] Saved checkpoint to "/tmp/tmp80w27qqo/mx-mod-0000.params"
# [07/26/2022 04:12:14 INFO 140426084742976] #progress_metric: host=algo-1, completed 86.66666666666667 % of epochs
# #metrics {"StartTime": 1658808734.2491925, "EndTime": 1658808734.3291264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4076.0, "count": 1, "min": 4076, "max": 4076}, "Total Batches Seen": {"sum": 43.0, "count": 1, "min": 43, "max": 43}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [07/26/2022 04:12:14 INFO 140426084742976] #throughput_metric: host=algo-1, train throughput=3546.6210609056047 records/second
# #metrics {"StartTime": 1658808734.3938975, "EndTime": 1658808734.393945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5068669700622559, "count": 1, "min": 0.5068669700622559, "max": 0.5068669700622559}}}
# #metrics {"StartTime": 1658808734.3940134, "EndTime": 1658808734.3940315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.4662358474731445, "count": 1, "min": 0.4662358474731445, "max": 0.4662358474731445}}}
# #metrics {"StartTime": 1658808734.394097, "EndTime": 1658808734.394112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.5631400489807129, "count": 1, "min": 0.5631400489807129, "max": 0.5631400489807129}}}
# #metrics {"StartTime": 1658808734.3941665, "EndTime": 1658808734.3941772, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.477879638671875, "count": 1, "min": 0.477879638671875, "max": 0.477879638671875}}}
# #metrics {"StartTime": 1658808734.394237, "EndTime": 1658808734.3942463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.3464587497711182, "count": 1, "min": 0.3464587497711182, "max": 0.3464587497711182}}}
# #metrics {"StartTime": 1658808734.3942997, "EndTime": 1658808734.394317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.3423753070831299, "count": 1, "min": 0.3423753070831299, "max": 0.3423753070831299}}}
# #metrics {"StartTime": 1658808734.3943753, "EndTime": 1658808734.3943865, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.34147446632385253, "count": 1, "min": 0.34147446632385253, "max": 0.34147446632385253}}}
# #metrics {"StartTime": 1658808734.3944411, "EndTime": 1658808734.3944583, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.3434841251373291, "count": 1, "min": 0.3434841251373291, "max": 0.3434841251373291}}}
# #metrics {"StartTime": 1658808734.394515, "EndTime": 1658808734.3945267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.5194872665405273, "count": 1, "min": 0.5194872665405273, "max": 0.5194872665405273}}}
# #metrics {"StartTime": 1658808734.3945835, "EndTime": 1658808734.3946002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.5671782684326172, "count": 1, "min": 0.5671782684326172, "max": 0.5671782684326172}}}
# #metrics {"StartTime": 1658808734.3946517, "EndTime": 1658808734.3946695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.48955644607543947, "count": 1, "min": 0.48955644607543947, "max": 0.48955644607543947}}}
# #metrics {"StartTime": 1658808734.3947155, "EndTime": 1658808734.3947344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.5233935356140137, "count": 1, "min": 0.5233935356140137, "max": 0.5233935356140137}}}
# #metrics {"StartTime": 1658808734.3947845, "EndTime": 1658808734.3947968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.33746095657348635, "count": 1, "min": 0.33746095657348635, "max": 0.33746095657348635}}}
# #metrics {"StartTime": 1658808734.394852, "EndTime": 1658808734.3948634, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.3494274616241455, "count": 1, "min": 0.3494274616241455, "max": 0.3494274616241455}}}
# #metrics {"StartTime": 1658808734.3949156, "EndTime": 1658808734.3949273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.34740180015563965, "count": 1, "min": 0.34740180015563965, "max": 0.34740180015563965}}}
# #metrics {"StartTime": 1658808734.3949804, "EndTime": 1658808734.3949995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.3432426929473877, "count": 1, "min": 0.3432426929473877, "max": 0.3432426929473877}}}
# #metrics {"StartTime": 1658808734.3950524, "EndTime": 1658808734.3950682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5295797920227051, "count": 1, "min": 0.5295797920227051, "max": 0.5295797920227051}}}
# #metrics {"StartTime": 1658808734.395117, "EndTime": 1658808734.3951309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.47506813049316404, "count": 1, "min": 0.47506813049316404, "max": 0.47506813049316404}}}
# #metrics {"StartTime": 1658808734.3952022, "EndTime": 1658808734.3952165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6039451599121094, "count": 1, "min": 0.6039451599121094, "max": 0.6039451599121094}}}
# #metrics {"StartTime": 1658808734.3952715, "EndTime": 1658808734.3952894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5225362205505371, "count": 1, "min": 0.5225362205505371, "max": 0.5225362205505371}}}
# #metrics {"StartTime": 1658808734.3953514, "EndTime": 1658808734.3953664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.4208706092834473, "count": 1, "min": 0.4208706092834473, "max": 0.4208706092834473}}}
# #metrics {"StartTime": 1658808734.3954227, "EndTime": 1658808734.395436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.4295635223388672, "count": 1, "min": 0.4295635223388672, "max": 0.4295635223388672}}}
# #metrics {"StartTime": 1658808734.3955052, "EndTime": 1658808734.395522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.45238012313842774, "count": 1, "min": 0.45238012313842774, "max": 0.45238012313842774}}}
# #metrics {"StartTime": 1658808734.3955705, "EndTime": 1658808734.3955877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.44544029235839844, "count": 1, "min": 0.44544029235839844, "max": 0.44544029235839844}}}
# #metrics {"StartTime": 1658808734.395651, "EndTime": 1658808734.395669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9239268112182617, "count": 1, "min": 0.9239268112182617, "max": 0.9239268112182617}}}
# #metrics {"StartTime": 1658808734.3957217, "EndTime": 1658808734.3957415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9512875366210938, "count": 1, "min": 0.9512875366210938, "max": 0.9512875366210938}}}
# #metrics {"StartTime": 1658808734.3957937, "EndTime": 1658808734.3958154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9489907455444336, "count": 1, "min": 0.9489907455444336, "max": 0.9489907455444336}}}
# #metrics {"StartTime": 1658808734.3958669, "EndTime": 1658808734.3959363, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.941324462890625, "count": 1, "min": 0.941324462890625, "max": 0.941324462890625}}}
# #metrics {"StartTime": 1658808734.3959925, "EndTime": 1658808734.396014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.020251579284668, "count": 1, "min": 1.020251579284668, "max": 1.020251579284668}}}
# #metrics {"StartTime": 1658808734.396068, "EndTime": 1658808734.3960834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.06804443359375, "count": 1, "min": 1.06804443359375, "max": 1.06804443359375}}}
# #metrics {"StartTime": 1658808734.396149, "EndTime": 1658808734.396165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.0057201385498047, "count": 1, "min": 1.0057201385498047, "max": 1.0057201385498047}}}
# #metrics {"StartTime": 1658808734.3962233, "EndTime": 1658808734.3962731, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9972785568237305, "count": 1, "min": 0.9972785568237305, "max": 0.9972785568237305}}}
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, epoch=13, train mse_objective <loss>=0.5068669700622559
# [07/26/2022 04:12:14 INFO 140426084742976] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=0.33746095657348635
# [07/26/2022 04:12:14 INFO 140426084742976] Saving model for epoch: 13
# [07/26/2022 04:12:14 INFO 140426084742976] Saved checkpoint to "/tmp/tmprepf0_oz/mx-mod-0000.params"
# [07/26/2022 04:12:14 INFO 140426084742976] Early stop condition met. Stopping training.
# [07/26/2022 04:12:14 INFO 140426084742976] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1658808734.329425, "EndTime": 1658808734.4041674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4360.0, "count": 1, "min": 4360, "max": 4360}, "Total Batches Seen": {"sum": 46.0, "count": 1, "min": 46, "max": 46}, "Max Records Seen Between Resets": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 284.0, "count": 1, "min": 284, "max": 284}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [07/26/2022 04:12:14 INFO 140426084742976] #throughput_metric: host=algo-1, train throughput=3792.728805680262 records/second
# [07/26/2022 04:12:14 WARNING 140426084742976] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/26/2022 04:12:14 WARNING 140426084742976] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('mse_objective', 27.304700824576365)
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('mse', 27.304700824576365)
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('absolute_loss', 4.142034718688105)
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('rmse', 5.225390016503684)
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('r2', 0.6568666693447567)
# [07/26/2022 04:12:14 INFO 140426084742976] #train_score (algo-1) : ('mae', 4.142034742194162)
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train mse_objective <loss>=27.304700824576365
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train mse <loss>=27.304700824576365
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train absolute_loss <loss>=4.142034718688105
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train rmse <loss>=5.225390016503684
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train r2 <loss>=0.6568666693447567
# [07/26/2022 04:12:14 INFO 140426084742976] #quality_metric: host=algo-1, train mae <loss>=4.142034742194162
# [07/26/2022 04:12:14 INFO 140426084742976] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [07/26/2022 04:12:14 INFO 140426084742976] Saved checkpoint to "/tmp/tmpihhk_8g0/mx-mod-0000.params"
# [07/26/2022 04:12:14 INFO 140426084742976] Test data is not provided.
# #metrics {"StartTime": 1658808732.987177, "EndTime": 1658808734.4390552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 232.27906227111816, "count": 1, "min": 232.27906227111816, "max": 232.27906227111816}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 8.746147155761719, "count": 14, "min": 0.20122528076171875, "max": 1.7466545104980469}, "update.time": {"sum": 1128.4253597259521, "count": 14, "min": 71.06614112854004, "max": 104.62069511413574}, "finalize.time": {"sum": 28.71227264404297, "count": 1, "min": 28.71227264404297, "max": 28.71227264404297}, "setuptime": {"sum": 35.74204444885254, "count": 1, "min": 35.74204444885254, "max": 35.74204444885254}, "totaltime": {"sum": 1749.0220069885254, "count": 1, "min": 1749.0220069885254, "max": 1749.0220069885254}}}
#
# 2022-07-26 04:12:33 Uploading - Uploading generated training model
# 2022-07-26 04:12:33 Completed - Training job completed
# Training seconds: 92
# Billable seconds: 92

# %%
model_name = f"{job_name}-model"
print(model_name)

region = boto3.Session().region_name
client = boto3.client("sagemaker", region_name=region)
info = client.describe_training_job(TrainingJobName=job_name)
model_data = info["ModelArtifacts"]["S3ModelArtifacts"]
print(model_data)

primary_container = {"Image": container, "ModelDataUrl": model_data}

create_model_response = client.create_model(
    ModelName=model_name, ExecutionRoleArn=role, PrimaryContainer=primary_container
)

print(create_model_response["ModelArn"])
# Out:
# boston-house-price-2022-07-26-04-09-13-model
# s3://sagemaker-us-east-1-980831117329/boston-house-price-2022-07-26-04-09-13/output/model.tar.gz
# arn:aws:sagemaker:us-east-1:980831117329:model/boston-house-price-2022-07-26-04-09-13-model

# %%
endpoint_config_name = f"boston-house-price-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
client = boto3.client("sagemaker", region_name=region)

print(endpoint_config_name)
create_endpoint_config_response = client.create_endpoint_config(
    EndpointConfigName=endpoint_config_name,
    ProductionVariants=[
        {
            "InstanceType": "ml.m5.xlarge",
            "InitialVariantWeight": 1,
            "InitialInstanceCount": 1,
            "ModelName": model_name,
            "VariantName": "AllTraffic",
        }
    ],
)

print(f"Endpoint Config Arn: {create_endpoint_config_response['EndpointConfigArn']}")
# Out:
# boston-house-price-2022-07-26-04-13-00
# Endpoint Config Arn: arn:aws:sagemaker:us-east-1:980831117329:endpoint-config/boston-house-price-2022-07-26-04-13-00

# %%
import time 
endpoint_name = f"boston-house-price-{strftime('%Y-%m-%d-%H-%M-%S', gmtime())}"
print(endpoint_name)

create_endpoint_response = client.create_endpoint(
    EndpointName=endpoint_name, EndpointConfigName=endpoint_config_name
)
print(create_endpoint_response["EndpointArn"])

resp = client.describe_endpoint(EndpointName=endpoint_name)
status = resp["EndpointStatus"]
while status == "Creating":
    print(f"Status: {status}")
    time.sleep(60)
    resp = client.describe_endpoint(EndpointName=endpoint_name)
    status = resp["EndpointStatus"]
# Out:
# boston-house-price-2022-07-26-04-13-00
# arn:aws:sagemaker:us-east-1:980831117329:endpoint/boston-house-price-2022-07-26-04-13-00
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
# Status: Creating
